# %%
# Instalação das bibliotecas necessárias
# Execute apenas uma vez
# !pip install tensorflow opencv-python matplotlib numpy

# %%
#Imports
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import tensorflow as tf
from pathlib import Path
import random

# %% [markdown]
# # Aumento de Dataset (Data Augmentation)
#
# Este notebook aplica técnicas de aumento de dados nas imagens originais para expandir o dataset:
#
# **Técnicas aplicadas:**
# - Imagens Originais
# - Flip Horizontal (espelhamento)
# - Ajuste de Tom (Hue)
# - Flip + Ajuste de Tom
#
# **Resultado:** Cada imagem original gera 4 variações, multiplicando o tamanho do dataset por 4x.
#
# **Saída:** As imagens processadas serão salvas em `naive_bayes_training/dataset_finalized/`

# %%
# Configurações de Caminho
path_raiz = Path("dataset")
directory_path = path_raiz

def salvar_imagem(img_data, pasta, nome):
    if hasattr(img_data, 'numpy'):
        dados = img_data.numpy()
    else:
        dados = img_data
    
    # NOVO: Garante que os dados estão no range [0, 1] e são float32
    dados = np.clip(dados, 0, 1)
    
    path_dest = pasta / nome
    # NOVO: cmap=None garante que ele não tente aplicar mapas de cores estranhos
    plt.imsave(str(path_dest), dados)

# Mapeamento de nomes das pastas originais para as finalizadas
nome_mapeamento = {
    "dataset_severe_accident": "dataset_final_severe_accident",
    "dataset_moderate_accident": "dataset_final_moderate_accident",
    "dataset_no_accident": "dataset_final_no_accident"
}

for folder_path in directory_path.iterdir():
    if folder_path.is_dir() and folder_path.name in nome_mapeamento:
        
        print(f"\n--- Processando Categoria: {folder_path.name} ---")

        # Usa o nome mapeado para a pasta final
        nome_final = nome_mapeamento[folder_path.name]
        new_name_folder = path_raiz.parent / "naive_bayes_training" / "dataset_finalized" / nome_final
        new_name_folder.mkdir(parents=True, exist_ok=True)

        for path_arquivo in folder_path.iterdir():
            if path_arquivo.suffix.lower() in ['.png', '.jpg', '.jpeg']:
                try:
                    # NOVO: Leitura e Normalização Imediata
                    img_raw = mpimg.imread(str(path_arquivo))
                    
                    # Se a imagem for 0-255 (inteiro), divide por 255 para virar 0-1 (float)
                    if img_raw.dtype == np.uint8 or np.max(img_raw) > 1.0:
                        img_raw = img_raw.astype(np.float32) / 255.0
                    
                    # NOVO: Remover canal Alpha (transparência) se existir
                    if img_raw.shape[-1] == 4:
                        img_raw = img_raw[:, :, :3]

                    # Converter para Tensor explicitamente
                    img_original = tf.cast(img_raw, tf.float32)

                    # --- 1. Original ---
                    salvar_imagem(img_original, new_name_folder, f"Original_{path_arquivo.name}")

                    # --- 2. Flip ---
                    img_flip = tf.image.flip_left_right(img_original)
                    salvar_imagem(img_flip, new_name_folder, f"Flip_{path_arquivo.name}")

                    # --- 3. Tom (Hue) ---
                    # Hue delta deve ser pequeno (entre -0.5 e 0.5)
                    img_tom = tf.image.adjust_hue(img_original, delta=random.uniform(-0.1, 0.1))
                    salvar_imagem(img_tom, new_name_folder, f"Tom_{path_arquivo.name}")

                    # --- 4. Flip + Tom (Hue) ---
                    # Delta positivo clareia, negativo escurece. Use valores pequenos.
                    img_claridade = tf.image.adjust_hue(img_flip, delta=random.uniform(-0.1, 0.1))
                    salvar_imagem(img_claridade, new_name_folder, f"Flip_Tom_{path_arquivo.name}")

                    print(f"Sucesso: {path_arquivo.name}")

                except Exception as e:
                    print(f"Erro em {path_arquivo.name}: {e}")

print("\n🚀 Processamento concluído! Verifique as pastas em 'naive_bayes_training/dataset_finalized/'.")
# Out:
# --- 📁 Processando Categoria: acidente_grave ---
# ✅ Sucesso: 000001.jpg
# ✅ Sucesso: 000002.jpg
# ✅ Sucesso: 000004.jpg
# ✅ Sucesso: 000005.jpg
# ✅ Sucesso: 000007.jpg
# ✅ Sucesso: 000008.jpg
# ✅ Sucesso: 000010.jpg
# ✅ Sucesso: 000014.jpeg
# ✅ Sucesso: 000015.jpg
# ✅ Sucesso: 000016.jpg
# ✅ Sucesso: 000017.jpg
# ✅ Sucesso: 000018.jpg
# ✅ Sucesso: 000019.jpg
# ✅ Sucesso: 000020.jpg
# ✅ Sucesso: 000021.jpg
# ✅ Sucesso: 000022.jpg
# ✅ Sucesso: 000026.jpg
# ✅ Sucesso: 000027.jpg
# ✅ Sucesso: 000028.jpg
# ✅ Sucesso: 000029.jpg
# ✅ Sucesso: 000030.jpg
# ✅ Sucesso: 000031.jpg
# ✅ Sucesso: 000033.jpg
# ✅ Sucesso: 000034.jpg
# ✅ Sucesso: 000035.jpg
# ✅ Sucesso: 000036.jpg
# ✅ Sucesso: 000037.jpg
# ✅ Sucesso: 000040.jpg
# ✅ Sucesso: 000041.jpg
# ✅ Sucesso: 000043.jpg
# ✅ Sucesso: 000044.jpg
# ✅ Sucesso: 000045.jpg
# ✅ Sucesso: 000047.jpg
# ✅ Sucesso: 000048.jpg
# ✅ Sucesso: 000049.jpg
# ✅ Sucesso: 000054.jpg
# ✅ Sucesso: 000055.jpg
# ✅ Sucesso: 000057.jpg
# ✅ Sucesso: 000067.jpg
# ✅ Sucesso: 000068.jpg
# ✅ Sucesso: 000069.jpg
# ✅ Sucesso: 000070.jpg
# ✅ Sucesso: 000073.jpg
# ✅ Sucesso: 000074.jpg
# ✅ Sucesso: 000075.jpg
# ✅ Sucesso: 000077.jpg
# ✅ Sucesso: 000078.jpg
# ✅ Sucesso: 000079.jpg
# ✅ Sucesso: 000081.jpg
# ✅ Sucesso: 000082.jpg
# ✅ Sucesso: 000085.jpg
# ✅ Sucesso: 000086.jpg
# ✅ Sucesso: 03.jpg
# ✅ Sucesso: acidente-grave-mata-duas-pessoas-entre-elas-uma-gravida-na-sc-350-no-alto-vale-do-itajai-1024x768.jpeg
# ✅ Sucesso: acidente.jpeg
# ✅ Sucesso: acidentesd.jpg
# ✅ Sucesso: caa10b71d47989efa3c74c02bec46050.jpg
# ✅ Sucesso: cidades-acidente-na-br-259-governador-valadares-acidente-em-governadorvaladares-1714941778.jpg
# ✅ Sucesso: Fim-de-semana-marcado-por-acidentes-fatais-na-regiao.jpg
# ✅ Sucesso: laranjeiras.jpg
#
# --- 📁 Processando Categoria: acidente_moderado ---
# ✅ Sucesso: 000026.jpg
# ✅ Sucesso: 000029.jpg
# ✅ Sucesso: 000032.jpg
# ✅ Sucesso: 000040.jpg
# ✅ Sucesso: 000041.jpg
# ✅ Sucesso: 000043.jpg
# ✅ Sucesso: 000044.jpg
# ✅ Sucesso: 000048.jpg
# ✅ Sucesso: 000049.jpg
# ✅ Sucesso: 000050.jpg
# ✅ Sucesso: 000054.jpg
# ✅ Sucesso: 000059.jpg
# ✅ Sucesso: 000061.jpg
# ✅ Sucesso: 000062.jpg
# ✅ Sucesso: 000065.jpg
# ✅ Sucesso: 2.A-car-involved-in-a-minor-accident.png
# ✅ Sucesso: 491937964_3111110679039272_3787317806594991890_n.jpg
# ✅ Sucesso: 504010275_2225680237888890_4699930498714037547_n.jpg
# ✅ Sucesso: 9-minor-injury-major-impact-why-even-small-accidents-deserve-legal-attention-scaled-r7slu6iirrj6gd4703luy5k6g26i1vkwkw4ftx56js.jpg
# ✅ Sucesso: AdobeStock_1350099761.jpg
# ✅ Sucesso: AdobeStock_178783215-1536x1024.jpeg
# ✅ Sucesso: AdobeStock_924009496-opt-1536x1024.jpeg
# ✅ Sucesso: Avocat-pour-un-accident-de-voiture-mineur-1024x682.jpg
# ✅ Sucesso: bigstock-Car-Has-Dented-Rear-Bumper-Dam-431809568-1920w.jpg
# ✅ Sucesso: broken-tail-light-cover-1536x864.jpg
# ✅ Sucesso: broken-taillight.jpg
# ✅ Sucesso: car-crash-accident-on-the-road-car-accident-for-insurance-claim-1536x614.jpeg.jpg
# ✅ Sucesso: carro-1.jpg
# ✅ Sucesso: carro-ficou-bastante-danificado-apos-capotamento-na-es-130-83885-article.jpg
# ✅ Sucesso: ChatGPT-Image-20-de-mai.-de-2025-15_02_26.jpg
# ✅ Sucesso: chipped-paintwork-dents-on-car.jpg
# ✅ Sucesso: closeup-dented-car-side-body-of-car-was-damaged-by-accident-in-traffic_t20_nRBrW6.jpg
# ✅ Sucesso: common-causes-of-collisions.jpg
# ✅ Sucesso: Como-tirar-amassados-do-veiculo-em-casa.jpg
# ✅ Sucesso: content-img-1.jpg
# ✅ Sucesso: Copy-of-Untitled-980x551.png
# ✅ Sucesso: crash-test-1620591_640.jpg
# ✅ Sucesso: image-1536x864.jpeg
# ✅ Sucesso: image1.jpg
# ✅ Sucesso: iStock-465663510-res.jpg
# ✅ Sucesso: iStock-90201067-1.jpg
# ✅ Sucesso: l-2.jpg
# ✅ Sucesso: minor-major-1080x675.jpg
# ✅ Sucesso: motor-vehicle-accident_Feature-Image_1000x563.jpg
# ✅ Sucesso: Parking-lot.jpeg
# ✅ Sucesso: qr-586-auto-reportagem-1.jpg
# ✅ Sucesso: raleigh-minor-car-accident-rear-bumper-damage.jpg
# ✅ Sucesso: RiverNorthCollisionRepair-272094-Fender-Bumper-Bender-blogbanner1-1920w.jpg
# ✅ Sucesso: RiverNorthCollisionRepair-314066-Crack-Silver-Bumper-blogbanner1-1920w.jpg
# ✅ Sucesso: shutterstock_412353520-768x480.jpg
# ✅ Sucesso: shutterstock_630848324-1024x683.jpg
# ✅ Sucesso: Side Impact Collision Repair.jpg
# ✅ Sucesso: touch-up-paint-on-car-minor-accident-v0-zfjh38qgu5od1.jpg
# ✅ Sucesso: Types-of-Vehicle-Damage-1200x480.jpg
# ✅ Sucesso: Visible-Dents-And-Scratches.jpg
# ✅ Sucesso: What-Are-Common-Causes-Of-Dent-And-Scratch-Damage.jpg
# ✅ Sucesso: When-Vehicle-Damage-Doesnt-Tell-the-Whole-Story-How-Minor-Accidents-Can-Cause-Major-Injuries-1-768x512.png.jpg
# ✅ Sucesso: When-Vehicle-Damage-Doesnt-Tell-the-Whole-Story-How-Minor-Accidents-Can-Cause-Major-Injuries-768x512.png.jpg
# ✅ Sucesso: When-Vehicle-Damage-Doesnt-Tell-the-Whole-Story-How-Minor-Accidents-Can-Cause-Major-Injuries.png.jpg
# ✅ Sucesso: Why-you-should-repair-small-dents-and-scratches-on-your-car.jpg
#
# --- 📁 Processando Categoria: nao_acidente ---
# ✅ Sucesso: 000004.jpg
# ✅ Sucesso: 000005.jpeg
# ✅ Sucesso: 000006.jpeg
# ✅ Sucesso: 000007.jpeg
# ✅ Sucesso: 000008.jpeg
# ✅ Sucesso: 000010.jpg
# ✅ Sucesso: 000011.jpeg
# ✅ Sucesso: 000011.jpg
# ✅ Sucesso: 000012.jpg
# ✅ Sucesso: 000014.jpeg
# ✅ Sucesso: 000014.jpg
# ✅ Sucesso: 000016.jpeg
# ✅ Sucesso: 000017.jpg
# ✅ Sucesso: 000018.jpeg
# ✅ Sucesso: 000018.jpg
# ✅ Sucesso: 000019.jpeg
# ✅ Sucesso: 000020.jpeg
# ✅ Sucesso: 000021.jpeg
# ✅ Sucesso: 000022.jpeg
# ✅ Sucesso: 000023.jpeg
# ✅ Sucesso: 000025.jpeg
# ✅ Sucesso: 000025.jpg
# ✅ Sucesso: 000026.jpeg
# ✅ Sucesso: 000027.jpeg
# ✅ Sucesso: 000028.jpeg
# ✅ Sucesso: 000029.jpeg
# ✅ Sucesso: 000029.jpg
# ✅ Sucesso: 000030.jpeg
# ✅ Sucesso: 000033.jpeg
# ✅ Sucesso: 000034.jpeg
# ✅ Sucesso: 000034.jpg
# ✅ Sucesso: 000036.jpeg
# ✅ Sucesso: 000038.jpeg
# ✅ Sucesso: 000039.jpeg
# ✅ Sucesso: 000040.jpg
# ✅ Sucesso: 000041.jpg
# ✅ Sucesso: 000043.jpeg
# ✅ Sucesso: 000043.jpg
# ✅ Sucesso: 000044.jpeg
# ✅ Sucesso: 000044.jpg
# ✅ Sucesso: 000045.jpeg
# ✅ Sucesso: 000046.jpeg
# ✅ Sucesso: 000046.jpg
# ✅ Sucesso: 000048.jpeg
# ✅ Sucesso: 000048.jpg
# ✅ Sucesso: 000049.jpeg
# ✅ Sucesso: 000049.jpg
# ✅ Sucesso: 000050.jpeg
# ✅ Sucesso: 000050.jpg
# ✅ Sucesso: 000051.jpeg
# ✅ Sucesso: 000053.jpeg
# ✅ Sucesso: 000053.jpg
# ✅ Sucesso: 000056.jpeg
# ✅ Sucesso: 000056.jpg
# ✅ Sucesso: 000060.jpg
# ✅ Sucesso: 000061.jpg
# ✅ Sucesso: 000066.jpeg
# ✅ Sucesso: 000067.jpg
# ✅ Sucesso: 000068.jpeg
# ✅ Sucesso: 000071.jpg
#
# 🚀 Processamento concluído! Verifique as pastas 'Dataset_Final_...' no seu disco.
